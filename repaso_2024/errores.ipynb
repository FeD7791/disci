# %% [markdown]
# # Errores 30/08/2024
#
# - La fuente de la mayoria esta en real python
# - El problema del semi-predicado: Una funcion o metodo devuelve un valor que puede tener dos significados distintos.
# - El problema es que nuestra funcion devuelve un valor ambiguo cuando no encuentra el elemento.
# - Soluciones
#     - Devolver un objeto que encapsule el resultado y su estado. Ejemplo de la libreria Go que tiene un objeto error que permite personalizar el error. Tambien en C es comun customizar el error.
#     - Utilizar tipos de datos opcionales: Esta opcion no tiene mucho sentido en python, debido a que el tipo de los objetos e muy flexible.
#     - Utilizar Excepciones
#
# ## Exceptions
#
# - Si el lenguaje utiliza excepciones, usar las excepciones!
# - El manejo de excepciones es el proceso de responder a la ocurrencia de excepciones: Condiciones anomalas o excepcionales querequieren un procesamiento especial durante la ejecucion de un programa.
# - Concepto de excepcion: El codigo corre en lineas que representan el estado normal del proceso. Hay como una linea que suele estar vacia y el codigo corre por alli cuando ocurre un problema.
# - LEER FILMINAS. 14.32
#
# ### Errores y exceptions
# Las palabras que utiliza python para manejar errores son:
# - assert
# - raise
# - try
# - except
# - else
# - finally
#
# Python tiene el concepto de excepcion. Nunca una excepcion llega a apagar el proceso. La excepcion se debe pensar como : No se mas que hacer.
#
# La primera excepcion es: Base excepcion que en jerarquia es hija de object. Despues de Base Exceptions sigue exception.
#
# En general se hereda de Exception y no de Base Exception.
#
# - La excepcion da informacion, la base exception no da informaion: 26.28 (video 2)
#
# - Exceptions - Traceback : El interprete de python muestra las llamadas a funciones que resultaron en el error.
#     - El interprete muestra el Stack Trace que consiste en una sucesion de errores en cada uno de las partes del codigo y codigos que hacian parte de este.
#     - Podemos usar raise para lanzar una excepcion si ocurre una condicion.
#     - La declaracion se puede complementar con una excepcion personalizada
#     - AssertionError : Para testing : Si utilizamos python -0 Nos omite el assert (python modo optimizado)
#     - Try - except : 40:44
#     - El with cierra el archivo que estas procesando unque haya una excepcion 0:45
#     - Es mejor cuando capturamos el error correcto 0:47:24
#     - Es util hacer capturas distintas, para distintos tipos de errores.
#     - Except funciona igual que ir, si no se ejecuta pasa al que sigue.
#     - Else : Va despues de todos los except.
#     - Es util que en una lectura de archivos uno vaya linea a linea con un try-except
#     - finally : Siempre se ejecuta. Por ejemplo el contexto with, tiene un finally, donde cierra siempre el archivo. Es muy normal pensar que un return en el try o except termina el codigo. Sin embargo esto no es asi. Se ejecuta justo antes de salir del bloque
#     - Herencia: Permite crear excepciones personalizadas mas especificas.
#     - Se puede agregar comportamiento a una excepcion: 0:58:20
#     - Warlus + herencia + exception : 0:59:00
#
#     - Warnings , ver filminas de Warning
#     - Se importa warnings
#     - warnings.warn(mensaje, UserWarning) 0.18.00
#     - Se puede controlar los warnings: python -W all script.py (Mostramos todos incluso los silenciados)
#     - python -W ignore script.py (silenciamos todos los warnings)
#     - Warning polimorfico 0:19:00
#     - Capturas de warnings utilizando contextos
#     - Creacion de Warnings Personalizados.
# - Notas:
#
#     Alan kay what i mean about objet oriented
#     Semillas en numpy: np.random.default_rng()
#     Se esta por deprecar: np.random.RandomState()
#     La semilla hay que ponerla fija.
